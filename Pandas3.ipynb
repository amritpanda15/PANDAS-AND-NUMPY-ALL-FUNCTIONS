# %%
  import pandas as pd

# %%
data=pd.read_csv('COVIDclinicaltrials.csv')

# %%
#data.shape
data.drop('Results First Posted',axis=1,inplace=True)

# %%
#Rename columns
#data.columns=['a','b','c','d','e','f','g','h','i','j']

data.isna().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    1378
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               414
# Outcome Measures             22
# Sponsor/Collaborators         0
# Gender                        5
# Age                           0
# Phases                     1127
# Enrollment                   22
# Funded Bys                    0
# Study Type                    0
# Study Designs                23
# Other IDs                     1
# Start Date                   22
# Primary Completion Date      23
# Completion Date              23
# First Posted                  0
# Last Update Posted            0
# Locations                   418
# Study Documents            2547
# URL                           0
# dtype: int64

# %%
data.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1     2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2     3  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 3     4  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# 4     5  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
#
#          Acronym      Status         Study Results  \
# 0   TMF-COVID-19  Recruiting  No Results Available
# 1    TAC-COVID19  Recruiting  No Results Available
# 2  COVID19-CHIEF  Recruiting  No Results Available
# 3   COVID-19 ORL  Recruiting  No Results Available
# 4            NaN  Recruiting  No Results Available
#
#                                           Conditions  \
# 0  Maternal Fetal Infection Transmission|COVID-19...
# 1                                            covid19
# 2                  Hepatocellular Carcinoma|COVID-19
# ...

# %%
#Checks for null Values, Returns Boolean Arrray
#data.isnull()
#Opposite of pd.isnull()
#data.notnull()
#for same task
#data.isna()
#data.notna()

# %%
#Drop all rows that contain null values
data.dropna()
# Out:
#       Rank   NCT Number                                              Title  \
# 60      61  NCT04341441  Will Hydroxychloroquine Impede or Prevent COVI...
# 248    249  NCT04427098  Enoxaparin in COVID-19 Moderate to Severe Hosp...
# 1078  1079  NCT04308668  Post-exposure Prophylaxis / Preemptive Therapy...
# 1267  1268  NCT03376854  Pilot RCT of Therapeutic Hypothermia Plus Neur...
# 1817  1818  NCT04366791  Radiation Eliminates Storming Cytokines and Un...
# 2101  2102  NCT04388514  Blood Ozonization in Patients With SARS-CoV-2 ...
# 2536  2537  NCT02517489  Community-Acquired Pneumonia : Evaluation of C...
# 2557  2558  NCT03827057  RECONsolidation of Traumatic Memories to ResOL...
# 2592  2593  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
#
#             Acronym      Status         Study Results  \
# 60    WHIP COVID-19  Recruiting  No Results Available
# 248     INHIXACOV19  Recruiting  No Results Available
# ...

# %%
#Drop all columns that contain null values
data.dropna(axis=1)

# %%
#Drop all rows have have less than n non null values
data.dropna(axis=1,thresh=10)
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 1        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 2        3  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 3        4  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# 4        5  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# ...    ...          ...                                                ...
# 2590  2591  NCT03261050  Target Engagement of a Novel Dissonance-Based ...
# 2591  2592  NCT03823469  Evaluating the Impact of a Culinary Coaching T...
# 2592  2593  NCT04429061  Reaching 90 90 90 in Adolescents in Zambia: Us...
# 2593  2594  NCT03922334                        Navigating New Motherhood 2
# 2594  2595  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
#
#             Acronym      Status         Study Results  \
# ...

# %%
#data.dropna(subset=["column_name"])

# %%
#Replace all null values with x
#Can be applied on a series or a data frame
data.fillna(200)

# %%
#Replace all null values with the mean (mean can be replaced with almost any function from the statistics module)
s=data['Year']
s.fillna(s.mean())
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, Length: 32445, dtype: int64

# %%
#Convert the datatype of the series to another type
s=data['Year']
s.astype(float)
# Out:
# 0        2019.0
# 1        2019.0
# 2        2019.0
# 3        2019.0
# 4        2019.0
#           ...
# 32440    2013.0
# 32441    2013.0
# 32442    2013.0
# 32443    2013.0
# 32444    2013.0
# Name: Year, Length: 32445, dtype: float64

# %%
#Replace all values equal to 1 with 'one'
#here s is series object (specific column)
#s.replace(1,'one')

# %%
#Replace all 1 with 'one' and 3 with 'three'
#s.replace([1,3],['one','three'])

# %%
#drop column 
data.drop(['Year'],axis=1)
#for complet delete
data.drop(['year'],axis=1,inplace=True)
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 32440                     Level 3                 ZZ11
# 32441                     Level 3                 ZZ11
# 32442                     Level 3                 ZZ11
# 32443                     Level 3                 ZZ11
# 32444                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
#to rename column name
#data.rename(columns={'Year':'Year_of_data'})
# Out:
#        Year_of_data Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0              2019                     Level 1                99999
# 1              2019                     Level 1                99999
# 2              2019                     Level 1                99999
# 3              2019                     Level 1                99999
# 4              2019                     Level 1                99999
# ...             ...                         ...                  ...
# 32440          2013                     Level 3                 ZZ11
# 32441          2013                     Level 3                 ZZ11
# 32442          2013                     Level 3                 ZZ11
# 32443          2013                     Level 3                 ZZ11
# 32444          2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
#Drop specified columns
data.drop(['Year', 'Industry_name_NZSIOC'], axis=1).head()
# Out:
#   Industry_aggregation_NZSIOC Industry_code_NZSIOC               Units  \
# 0                     Level 1                99999  Dollars (millions)
# 1                     Level 1                99999  Dollars (millions)
# 2                     Level 1                99999  Dollars (millions)
# 3                     Level 1                99999  Dollars (millions)
# 4                     Level 1                99999  Dollars (millions)
#
#   Variable_code                                    Variable_name  \
# 0           H01                                     Total income
# 1           H04  Sales, government funding, grants and subsidies
# 2           H05                Interest, dividends and donations
# 3           H07                             Non-operating income
# 4           H08                                Total expenditure
#
#        Variable_category    Value  \
# 0  Financial performance  728,239
# 1  Financial performance  643,809
# 2  Financial performance   62,924
# ...
