# %%
import pandas as pd

# %%
data=pd.read_csv('/Users/admin/Downloads/annual-enterprise-survey-2019-financial-year-provisional-csv.csv')

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df = pd.DataFrame(d1)

# %%
df
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
#Pandas melt() function is used to change the DataFrame format from wide to long.
#It’s used to create a specific format of the DataFrame object where one or more 
#columns work as identifiers. All the remaining 
#columns are treated as values and unpivoted to the row axis and only two columns – variable and value.
pd.melt(df)
# Out:
#   variable   value
# 0     Name  Pankaj
# 1     Name    Lisa
# 2     Name   David
# 3       ID       1
# 4       ID       2
# 5       ID       3
# 6     Role     CEO
# 7     Role  Editor
# 8     Role  Author

# %%
df_melt=pd.melt(df,id_vars=["ID"], value_vars=["Name", "Role"], var_name="Attribute", value_name="Value")
#df_melt
#unmelting using pivot()
df_unmelt=df_melt.pivot(index='ID', columns='Attribute')

# %%
df_unmelt
# Out:
#             Value
# Attribute    Name    Role
# ID
# 1          Pankaj     CEO
# 2            Lisa  Editor
# 3           David  Author

# %%
d2 = {"Name": ["Pankaj"], "ID": [1], "Role": ["CEO"]}
df1=pd.DataFrame(d2)
#Append rows of DataFrames
new_df=pd.concat([df,df1],ignore_index=True)
new_df
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author
# 3  Pankaj   1     CEO

# %%
#Append columns of DataFrames
d3={"city":['Delhi','Noida','Aligarh']}
df2=pd.DataFrame(d3)

# %%
pd.concat([df,df2],axis=1)
# Out:
#      Name  ID    Role     city
# 0  Pankaj   1     CEO    Delhi
# 1    Lisa   2  Editor    Noida
# 2   David   3  Author  Aligarh

# %%
row=['Delhi','Noida','Aligarh']
df['city']=row
df
# Out:
#      Name  ID    Role     city
# 0  Pankaj   1     CEO    Delhi
# 1    Lisa   2  Editor    Noida
# 2   David   3  Author  Aligarh

# %%
#Remove duplicate rows (only considers columns).
#inplace=True
new_df.drop_duplicates(inplace=True)
new_df
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
#Randomly select n rows
data.sample(n=20)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 28051  2013                     Level 4                AA131
# 25901  2014                     Level 1                   II
# 20813  2015                     Level 4                FF116
# 15835  2016                     Level 3                 EE12
# 12796  2017                     Level 4                LL122
# 3480   2019                     Level 4                LL112
# 21780  2015                     Level 3                 KK12
# 17417  2016                     Level 3                 LL12
# 9225   2018                     Level 4                RS214
# 14014  2016                     Level 4                AA111
# 1282   2019                     Level 4                CC711
# 13088  2017                     Level 3                 MN21
# 9501   2017                     Level 4                AA131
# 17316  2016                     Level 3                 LL11
# ...

# %%
#Randomly select fraction of rows
#Generating 20% sample of data frame
data.sample(frac=0.20)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 14783  2016                     Level 4                CC411
# 19371  2015                     Level 3                 CC41
# 22122  2015                     Level 4                LL123
# 24011  2014                     Level 3                 CC41
# 5501   2018                     Level 4                CC411
# ...     ...                         ...                  ...
# 8588   2018                     Level 1                   OO
# 17715  2016                     Level 4                MN115
# 21550  2015                     Level 1                   JJ
# 23468  2014                     Level 4                AA141
# 30545  2013                     Level 1                   II
#
#                                Industry_name_NZSIOC               Units  \
# 14783                                      Printing  Dollars (millions)
# 19371                                      Printing  Dollars (millions)
# ...

# %%
#Count number of rows with each unique value of variable
data['Year'].value_counts()
# Out:
# 2015    4635
# 2014    4635
# 2013    4635
# 2019    4635
# 2018    4635
# 2017    4635
# 2016    4635
# Name: Year, dtype: int64

# %%
#of rows in DataFrame
len(data)
# Out:
# 32445

# %%
#distinct values in a column
data['Year'].nunique()
# Out:
# 7

# %%
#Sum values of each object.
#data['Year'].sum()

#Count non-NA/null values of each object
#data['Year'].count()

#Minimum value in each object
#data.min()
#or 
#data['Year'].min()

#Maximum value in each object.
#data['Year'].max()

#Mean value of each object.
#data['Year'].mean()

#Median value of each object
#data['Year'].median()

#Variance of each object
#data['Year'].var()

#Standard deviation of each object.
#data['Year'].std()

#Returns the correlation between columns in a DataFrame
#data.corr()

# %%
#Make new column
df['newcol']=df['ID']+1
df
# Out:
#      Name  ID    Role     city  newcol
# 0  Pankaj   1     CEO    Delhi       2
# 1    Lisa   2  Editor    Noida       3
# 2   David   3  Author  Aligarh       4

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df1 = pd.DataFrame(d1)

d2 = {"Name": ["Amit", "Deepak", "Ram"], "ID": [4, 2, 6], "Role": ["CEO", "Sales", "Marketing"]}
df2 = pd.DataFrame(d2)

# %%
#Join matching rows from df1 to df2.
#pd.merge(df1,df2,on='ID')

#how=left,right,outer,inner
pd.merge(df1,df2,on='ID',how='right')
# Out:
#   Name_x  ID  Role_x  Name_y     Role_y
# 0   Lisa   2  Editor  Deepak      Sales
# 1    NaN   4     NaN    Amit        CEO
# 2    NaN   6     NaN     Ram  Marketing

# %%
new_data=data.groupby(by=['Year','Variable_code'])
new_data.head()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 28444  2013                     Level 4                CC211
# 30907  2013                     Level 1                   KK
# 30941  2013                     Level 3                 KK11
# 30975  2013                     Level 4                KK111
# 31009  2013                     Level 4                KK112
#
#                     Industry_name_NZSIOC               Units Variable_code  \
# 0                         All industries  Dollars (millions)           H01
# 1                         All industries  Dollars (millions)           H04
# ...

# %%
#Size of each group.
new_data.size()
# Out:
# Year  Variable_code
# 2013  H01              139
#       H02               52
#       H03               52
#       H04               78
#       H05              139
#                       ...
# 2019  H37              134
#       H38               52
#       H39              139
#       H40              139
#       H41              139
# Length: 273, dtype: int64
